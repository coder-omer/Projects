# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "RFM Customer Segmentation & Cohort Analysis Project". This is the first project of the Capstone Project Series, which consists of 3 different project that contain different scenarios.
#
# This is a project which you will learn what is RFM? And how to apply RFM Analysis and Customer Segmentation using K-Means Clustering. Also you will improve your Data Cleaning, Data Visualization and Exploratory Data Analysis capabilities. On the other hand you will create Cohort and Conduct Cohort Analysis.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - **NOTE:** This Project assumes that you already know the basics of coding in Python and are familiar with the theory behind K-Means Clustering.

# %% [markdown]
# # #Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***K-Means Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Bu, İngiltere merkezli ve kayıtlı mağaza dışı çevrimiçi perakende için 01/12/2010 ile 09/12/2011 arasında gerçekleşen tüm işlemleri içeren uluslararası bir veri setidir. Şirket esas olarak benzersiz her durum için hediyeler satıyor. Şirketin birçok müşterisi toptancıdır.
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and K-Means Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying K-Means Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions. In addition, the data you apply for K-Means should be normalized.
#
# On the other hand, you should inform the K-means algorithm about the number of clusters it will predict. You will also try the *** Elbow method *** and *** Silhouette Analysis *** to find the optimum number of clusters.
#
# After the above operations, you will have made cluster estimation with K-Means. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
#
# Öncelikle verilerin yapısını ve eksik değerleri gözlemlemek için keşifsel veri analizi ve veri görselleştirme tekniklerini kullanabilirsiniz.
#
# Tanımlayıcı analiz yapmalısınız. Çünkü özelliklerin birbirleriyle olan ilişkisini anlamanız ve verilerdeki gürültü ve eksik değerleri temizlemeniz gerekir. Bundan sonra veri seti RFM analizi için hazır olacaktır.
#
# RFM Analizine başlamadan önce, *Siparişler*, *Müşteriler* ve *Ülkeler* dağılımı ile ilgili bazı analizler yapmanız istenecektir. Bu analizler, şirketin satış politikalarını geliştirmesine yardımcı olacak ve kaynakların doğru kullanımına katkıda bulunacaktır.
#
# İngiltere'nin yalnızca en fazla satış gelirine sahip olmadığını, aynı zamanda en çok müşteriye sahip olduğunu fark edeceksiniz. Dolayısıyla bir sonraki RFM Analizi, Müşteri Segmentasyonu ve K-Means Kümeleme konularında yalnızca Birleşik Krallık işlemlerini analiz etmeye devam edeceksiniz.
#
# Ardından, müşterilerin geçmişteki satın alma davranışlarına dayalı bir müşteri segmentasyon tekniği olan RFM Analizine başlayacaksınız.
#
# RFM Analizi kullanarak şirketlerin müşterilerini daha iyi tanımaları, trendleri daha iyi gözlemlemeleri, müşteri tutma ve satış gelirlerini artırmaları için farklı müşteri segmentlerine farklı yaklaşımlar geliştirmelerini sağlayabilirsiniz.
#
# İngiltere işlemlerinden oluşan verileri kullanarak yapacağınız RFM Analizinde müşterilerin Yenilik, Frekans ve Parasal değerlerini hesaplayacaksınız. Son olarak, bu değerleri içeren bir RFM tablosu oluşturmanız gerekir.
#
# Müşteri Segmentasyonu bölümünde, RFM tablosunu kullanarak müşterilerinizi segmentlere ayırdığınız bir RFM Segmentasyon Tablosu oluşturacaksınız. Örneğin, en iyi müşteriyi "Büyük Harcayanlar" ve kayıp müşteriyi "Kayıp Müşteri" olarak etiketleyebilirsiniz.
#
# Müşterileri, güncelliklerine, sıklıklarına ve parasal değerlerine göre kendimiz segmentlere ayıracağız. Ancak bir **denetimsiz öğrenme** modeli bunu bizim için daha iyi yapabilir mi? Bu sorunun cevabını bulmak için K-Means algoritmasını kullanacaksınız. Ardından algoritmanın yaptığı sınıflandırmayı kendi yaptığınız sınıflandırma ile karşılaştıracaksınız.
#
# K-Means Clustering uygulamadan önce veri ön işlemesi yapmalısınız. Bu bağlamda özellik korelasyonlarının ve dağılımlarının incelenmesi faydalı olacaktır. Ayrıca K-Means için başvurduğunuz veriler normalize edilmelidir.
#
# Öte yandan, K-means algoritmasına tahmin edeceği küme sayısı hakkında bilgi vermelisiniz. Optimum küme sayısını bulmak için *** Dirsek yöntemini *** ve *** Siluet Analizini *** de deneyeceksiniz.
#
# Yukarıdaki işlemlerden sonra K-Means ile küme tahmini yapmış olacaksınız. Bir dağılım grafiği kullanarak küme dağılımını görselleştirmelisiniz. Boxplot yardımıyla ortaya çıkan kümelerin özelliklerini gözlemleyebilirsiniz. Böylece kümeleri etiketleyebilecek ve sonuçları yorumlayabileceksiniz.
#
# Son olarak, daha önce yapmış olduğunuz analizden bağımsız olarak başlangıçta kullandığınız verilerle Kohort Analizi yapacaksınız. Kohort analizi, kullanıcı verilerini alan ve bunları analiz için ilgili gruplara ayıran bir davranışsal analitik alt kümesidir. Bu analiz ayrıca müşteri segmentasyonu yapmak ve elde tutma, kayıp ve yaşam boyu değer gibi metrikleri izlemek için kullanılabilir.

# %% [markdown]
# # #Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying K-Means Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# # #Tasks
#
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*
#
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*
#
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
# - Plot RFM Segments
#
# #### 4. Applying K-Means Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
# - K-Means Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*
#
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*
#
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings('ignore')
#pd.set_option('display.max_rows', 500)

# %%
#pip install openpyxl

# %%
df = pd.read_excel("Online Retail.xlsx")  # burada invoiceno ve customerid nin birden fazla satırda tekrarlayabildiğini gördüm

# %%
df_copy = df.copy  # datanın kopyasını alıp, onun üzerinde işlemlerimizi yapalım

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()     # object sütunların hangileri olduğuna baktım. null değerler olduğunu görüyorum
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()  # null değerler description ve CustomerID de. CustomerID olmayan sütunları düşürebilirim.
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.describe().T  # outlier değerler olduğu göze çarpıyor
# Out:
#                count          mean          std       min       25%       50%  \
# Quantity    541909.0      9.552250   218.081158 -80995.00      1.00      3.00
# UnitPrice   541909.0      4.611114    96.759853 -11062.06      1.25      2.08
# CustomerID  406829.0  15287.690570  1713.600303  12346.00  13953.00  15152.00
#
#                  75%      max
# Quantity       10.00  80995.0
# UnitPrice       4.13  38970.0
# CustomerID  16791.00  18287.0

# %%
# def summary(df):
#     display(df.head())
#     print('-'*100)
#     display(df.info())
#     print('-'*100)
#     display(df.describe([0.01,0.25,0.50,0.75,0.99]))
# summary(df)

# %%
df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %%
df["Country"].value_counts()    # United Kingdom ın ezici üstünlüğü var.
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
uk_rate = df["Country"].value_counts()[0] / df["Country"].count()   # UK nin toplam datadaki ağırlığı
uk_rate
# Out:
# 0.9143195628786382

# %%
df.isnull().sum().sum() # toplam null sayısı
# Out:
# 136534

# %%
df.isnull().sum().sum()/df.shape[0]       # toplam null sayısının toplam data sayısına oranı
# Out:
# 0.2519500506542611

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %% [markdown]
# We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.

# %%
df[(df['Quantity'] < 0)]  # quantity eksi değerde olan satırlar
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[(df['UnitPrice'] < 0)]  # unitprice eksi değerde olan satırlar
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df[df["InvoiceNo"].str.startswith('A', na=False)]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# ### ii. What does the letter "C" in the InvoiceNo column mean?

# %% [markdown]
# hint: If the invoice number starts with the letter "C", it means the order was cancelled. Or those who abandon their order.

# %%
df[df["InvoiceNo"].str.startswith('C', na=False)]
# Bu veri setinde C harfi ile başlayan Fatura ID'leri iade faturası olduğunu göstermektedir. Bu analiz için iade faturalarını sileceğim.
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# When we filter canceled orders by Quantity> 0 or filter non-canceled orders by Quantity <0 nothing returns, this confirms that negative values mean the order was canceled. So lets find out how many orders were cancelled?

# %%
df[(df['Quantity'] > 0)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[(df['Quantity'] < 0)]   # iptal edilmiş orderlar, C ile başlıyorlar.
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# #### Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
df[(df['UnitPrice'] < 0)]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# ### iii. Handling Missing Values

# %% [markdown]
# Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.
#
# We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.

# %%
df.CustomerID.isnull().sum()    # customer id si boş olan kaç satır var, ona tekrar baktım
# Out:
# 135080

# %%
df[df["CustomerID"].isnull()] #kolon 1 NAN olan değerler geldi
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %%
df.dropna(subset=['CustomerID'], inplace=True)  #customer id'si boş olan satırları düşürdüm

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
#df.isnull().sum()     
#tekrar df'te null olup olmadığına baktım. customer id'si boş olan satırları düşürünce,  description daki nullar da gitmiş.

# %%
#df.shape

# %%
df[(df['Quantity'] < 0)]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.drop(df[(df['Quantity'] < 0)].index, inplace = True)  # df['Quantity'] < 0 lar düşürülünce 397924 row kalıyor.

# %%
df[(df['UnitPrice'] < 0)]  
# df['Quantity'] < 0 lar düşürülünce, df['UnitPrice'] < 0 kalmamış.
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
# A ile ve C ile başlayan invoice no var mı diye de kontrol ettim, kalmadığını gördüm. Kalsalardı düşürecektim.

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# 1. Find the unique number of InvoiceNo  per customer

# %%
df.groupby('CustomerID')['InvoiceNo'].unique()    # müşterilerin unique invoice noları
# Out:
# CustomerID
# 12346.0                                             [541431]
# 12347.0    [537626, 542237, 549222, 556201, 562032, 57351...
# 12348.0                     [539318, 541998, 548955, 568172]
# 12349.0                                             [577609]
# 12350.0                                             [543037]
#                                  ...
# 18280.0                                             [545712]
# 18281.0                                             [556464]
# 18282.0                                     [562525, 580173]
# 18283.0    [540350, 541854, 545079, 550957, 554157, 55673...
# 18287.0                             [554065, 570715, 573167]
# Name: InvoiceNo, Length: 4339, dtype: object

# %%
df.groupby('CustomerID')['InvoiceNo'].nunique() # müşterilerin unique invoice nolarının sayıları
# Out:
# CustomerID
# 12346.0     1
# 12347.0     7
# 12348.0     4
# 12349.0     1
# 12350.0     1
#            ..
# 18280.0     1
# 18281.0     1
# 18282.0     2
# 18283.0    16
# 18287.0     3
# Name: InvoiceNo, Length: 4339, dtype: int64

# %% [markdown]
# 2. What's the average number of unqiue items per order or per customer?

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.groupby(['InvoiceNo'])['StockCode'].nunique().mean() # the average number of unqiue items per order.
# Out:
# 20.925496331463098

# %% [markdown]
# 3. Let's see how this compares to the number of unique products per customer.

# %%
df.groupby(['CustomerID'])['StockCode'].nunique().mean()  # the average number of unqiue items per customer.
# Out:
# 61.48928324498733

# %%
group1 = df.groupby(['CustomerID', 'InvoiceNo'])['StockCode'].nunique() 
group1.mean()
# bir müşterinin faturasndaki unique ürün sayısının ortalaması
# Out:
# 20.925496331463098

# %% [markdown]
# ### vi. Explore Customers by Country

# %% [markdown]
# 1. What's the total revenue per country?

# %%
df["total_revenue"] = df["Quantity"]*df["UnitPrice"]

# %%
df.groupby("Country").agg({"total_revenue":"sum"}).sort_values(by='total_revenue', ascending=False)  #ülkelere ait unique toplam gelirler. büyükten küçüğe.
# Out:
#                       total_revenue
# Country
# United Kingdom          7308391.554
# Netherlands              285446.340
# EIRE                     265545.900
# Germany                  228867.140
# France                   209024.050
# Australia                138521.310
# Spain                     61577.110
# Switzerland               56443.950
# Belgium                   41196.340
# Sweden                    38378.330
# Japan                     37416.370
# Norway                    36165.440
# Portugal                  33439.890
# Finland                   22546.080
# Singapore                 21279.290
# Channel Islands           20450.440
# Denmark                   18955.340
# Italy                     17483.240
# Cyprus                    13590.380
# Austria                   10198.680
# Poland                     7334.650
# Israel                     7221.690
# Greece                     4760.520
# Iceland                    4310.000
# Canada                     3666.380
# ...

# %% [markdown]
# 2. Visualize number of customer per country

# %%
noc_country = df.groupby ("Country")[["CustomerID"]].nunique().sort_values(by='CustomerID', ascending=False)   #ülkelere ait unique customer ların sayıları. büyükten küçüğe.
noc_country
# Out:
#                       CustomerID
# Country
# United Kingdom              3921
# Germany                       94
# France                        87
# Spain                         30
# Belgium                       25
# Switzerland                   21
# Portugal                      19
# Italy                         14
# Finland                       12
# Austria                       11
# Norway                        10
# Netherlands                    9
# Australia                      9
# Denmark                        9
# Channel Islands                9
# Cyprus                         8
# Sweden                         8
# Japan                          8
# Poland                         6
# USA                            4
# Canada                         4
# Unspecified                    4
# Greece                         4
# EIRE                           3
# Israel                         3
# Malta                          2
# United Arab Emirates           2
# ...

# %%
noc_country.plot(kind="bar", figsize=(6,4))   
#bar grafiği olarak göstermek istersek yine aynı üstünlüğü görebiliyoruz
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# 3. Visualize total cost per country

# %%
cost_country = df.groupby ("Country")["total_revenue"].sum()
cost_country.plot(kind="pie", figsize=(6,4))        # pie grafiği olarak gösterdiğimizde UKnin revenue için de çoğunluğu aldığı görülüyor
# Out:
# <AxesSubplot:ylabel='total_revenue'>

# %%
cost_country.plot(kind="bar", figsize=(6,4))   
#bar grafiği olarak göstermek istersek yine aynı üstünlüğü görebiliyoruz
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %% [markdown]
# ### vii. Explore the UK Market

# %%
df.shape
# Out:
# (397924, 9)

# %% [markdown]
# 1. Create df_uk DataFrame

# %%
df_uk = df[df['Country'] == 'United Kingdom']     # UK dataframe i oluşturdum
df_uk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df_uk.duplicated().sum()
# Out:
# 5118

# %%
df_uk.drop_duplicates(ignore_index=True, inplace=True)

# %%
df_uk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 349222    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 349223    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 349224    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 349225    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 349226    581586     20685                DOORMAT RED RETROSPOT        10
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %% [markdown]
# 2. What are the most popular products that are bought in the UK?

# %%
df_uk.groupby('StockCode')[['Quantity']].sum().sort_values(by='Quantity', ascending=False) #uk'de en büyük miktarda satılan ürünler
# Out:
#            Quantity
# StockCode
# 23843         80995
# 23166         76919
# 84077         49086
# 22197         45609
# 85099B        41878
# ...             ...
# 90025F            1
# 90039C            1
# 90021             1
# 21895             1
# 35650             1
#
# [3645 rows x 1 columns]

# %%
df_uk[df_uk.StockCode==23843]   # UK'de en büyük miktarda satılan ürün bir seferde satılmış
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 348876    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 348876 2011-12-09 09:15:00       2.08     16446.0  United Kingdom
#
#         total_revenue
# 348876       168469.6

# %%
df_uk.groupby(['Description'])['Quantity'].sum().sort_values(ascending=False)  # burada da en büyük miktarda satılan ürünlerin neler olduğunu gösterdim
# Out:
# Description
# PAPER CRAFT , LITTLE BIRDIE            80995
# MEDIUM CERAMIC TOP STORAGE JAR         76919
# WORLD WAR 2 GLIDERS ASSTD DESIGNS      49086
# JUMBO BAG RED RETROSPOT                41878
# WHITE HANGING HEART T-LIGHT HOLDER     34630
#                                        ...
# DUSTY PINK CHRISTMAS TREE 30CM             1
# GREEN PENDANT TRIPLE SHELL NECKLACE        1
# PINK POLKADOT KIDS BAG                     1
# SET/3 TALL GLASS CANDLE HOLDER PINK        1
# RUBY GLASS CLUSTER EARRINGS                1
# Name: Quantity, Length: 3844, dtype: int64

# %%
df_uk.groupby(['StockCode','Description'])['InvoiceNo'].count().sort_values(ascending=False) 
# UK'de satış sayısı(kaç faturada yer aldığı) en çok olan ürünler. en popüler ürünler diyebiliriz. bu ifade en büyük miktarda bunların aldığını söylemiyor.
# Out:
# StockCode  Description
# 85123A     WHITE HANGING HEART T-LIGHT HOLDER    1929
# 85099B     JUMBO BAG RED RETROSPOT               1461
# 22423      REGENCY CAKESTAND 3 TIER              1417
# 84879      ASSORTED COLOUR BIRD ORNAMENT         1320
# 47566      PARTY BUNTING                         1301
#                                                  ...
# 22952      72 CAKE CASES VINTAGE CHRISTMAS          1
# 84877A     PINK ROUND COMPACT MIRROR                1
# 23502      PLAYING CARDS VINTAGE DOILEY             1
# 22776      CAKESTAND, 3 TIER, LOVEHEART             1
# 84795C     OCEAN STRIPE HAMMOCK                     1
# Name: InvoiceNo, Length: 3864, dtype: int64

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %% [markdown]
# # 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
# **************************
# İnternet ve e-ticaret çağında, işlerini çevrimiçi olarak genişletmeyen veya müşterilerine ulaşmak için dijital araçlar kullanmayan şirketler, ölçeklenebilirlik ve dijital varlık eksikliği gibi sorunlarla karşılaşacak. E-ticaret işletmelerinin müşteri değerini analiz etmek ve tahmin etmek için kullandıkları önemli bir pazarlama stratejisi müşteri segmentasyonudur. Müşteri verileri, müşterileri davranışlarına ve tercihlerine göre gruplara ayırmak için kullanılır.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Yenilik, Frekans, Parasal) Analizi**, geçmiş satın alma davranışına dayalı olarak müşteri değerini analiz etmeye yönelik bir müşteri segmentasyonu tekniğidir. RFM analizi ilk olarak doğrudan posta endüstrisi tarafından kırk yılı aşkın bir süre önce kullanıldı, ancak yine de pazarlamanızı optimize etmenin etkili bir yoludur.
# <br>
# <br>
# Bu Defterdeki amacımız, veri kümemizdeki müşterileri şu şekilde kümelemektir:
#  - En değerli müşterilerimizi tanımak
#  - Geliri artırın
#  - Müşteriyi elde tutmayı artırın
#  - Müşterilerimizin eğilimleri ve davranışları hakkında daha fazla bilgi edinin
#  - Risk altındaki müşterileri tanımlayın
#
# **RFM Analizi** ile başlayacağız ve ardından bulgularımızı **K-Ortalama Kümeleme Algoritmaları** kullanarak tahmine dayalı analizle tamamlayacağız.
#
# - YENİLİK (R): Son satın alma tarihinden itibaren geçen süre
# - SIKLIK (F): Toplam satın alma sayısı
# - PARASAL DEĞER (M): Toplam parasal değer
#
# ***********************
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?
#
#  ************************
#  RFM Analizinin Faydaları
#
# - Artan müşteri tutma
# - Artan yanıt oranı
# - Artan dönüşüm oranı
# - Gelir artışı
#
# RFM Analizi aşağıdaki soruları yanıtlar:
#   - En iyi müşterilerimiz kimler?
#   - Kimin daha karlı müşterilere dönüşme potansiyeli var?
#   - Hangi müşterileri elde tutmamız gerekiyor?
#   - Pazarlama kampanyamıza en çok hangi müşteri grubu yanıt verir?
#
# ******************************

# %% [markdown]
# ### i. Import Libraries

# %%
import datetime as dt

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %%
df_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_revenue
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom          15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom          22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34

# %%
df_uk.shape
# Out:
# (349227, 9)

# %%
df_uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349227 entries, 0 to 349226
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   InvoiceNo      349227 non-null  object
#  1   StockCode      349227 non-null  object
#  2   Description    349227 non-null  object
#  3   Quantity       349227 non-null  int64
#  4   InvoiceDate    349227 non-null  datetime64[ns]
#  5   UnitPrice      349227 non-null  float64
#  6   CustomerID     349227 non-null  float64
#  7   Country        349227 non-null  object
#  8   total_revenue  349227 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 24.0+ MB

# %%
df_uk.isnull().sum()
# Out:
# InvoiceNo        0
# StockCode        0
# Description      0
# Quantity         0
# InvoiceDate      0
# UnitPrice        0
# CustomerID       0
# Country          0
# total_revenue    0
# dtype: int64

# %%
df_uk.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions
#
# **********************
# ### iii. Yenilik: Son satın alma tarihinden itibaren geçen gün sayısı
# Yenilik değerlerini hesaplamak için sırasıyla şu adımları izleyin:
#
# 1. Yeniliği hesaplamak için, müşterinin son satın alma işleminin kaç gün önce olduğunu değerlendirmek için referans noktası olarak bir tarih seçmemiz gerekir.
# 2. Zaman damgası olmadan fatura tarihini içeren Tarih adlı yeni bir sütun oluşturun.
# 3. Müşteri Kimliğine göre gruplandırın ve son satın alma tarihini kontrol edin
# 4. Son satın alma tarihinden itibaren geçen günleri hesaplayın
# 5. Artık ihtiyacımız olmadığı için Last_Purchase_Date'i bırakın
# 6. RFM dağılımlarını çizin
# **********************

# %% [markdown]
# 1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.

# %%
df_uk1 = df_uk.copy()

# %%
max(df_uk1.InvoiceDate) # referans tarihi için son işlemin yapıldığı tarihe baktım. saatle baraber döndü.
# df['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:49:00')

# %%
reference_date = dt.date(2011,12,10)   # son işlemin yapılmış olduğu tarihten bir gün sonrasını referans olarak aldım.
reference_date                         # bu reference date benim müşterinin son alımından itibaren kaç gün geçtiğini baz alacağım tarih
# Out:
# datetime.date(2011, 12, 10)

# %% [markdown]
# 2. Create a new column called Date which contains the invoice date without the timestamp

# %%
df_uk1["date"] = df_uk["InvoiceDate"].dt.date     # invoice date in sadece tarih kısımlarını alarak date adlı yeni bir sütun oluşturdum. fatura tarihleri.
df_uk1.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_revenue  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom          15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom          22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
#
#          date
# 0  2010-12-01
# 1  2010-12-01
# 2  2010-12-01
# 3  2010-12-01
# 4  2010-12-01

# %% [markdown]
# 3. Group by CustomerID and check the last date of purchase

# %%
# df_uk1.groupby("CustomerID")["date"].transform(max)      #date'leri CustomerID'ye göre grupladım. max olanları döndürdüm.

# %%
df_recency = df_uk1.groupby(by='CustomerID', as_index=False)['date'].max()
df_recency
# Out:
#       CustomerID        date
# 0        12346.0  2011-01-18
# 1        12747.0  2011-12-07
# 2        12748.0  2011-12-09
# 3        12749.0  2011-12-06
# 4        12820.0  2011-12-06
# ...          ...         ...
# 3916     18280.0  2011-03-07
# 3917     18281.0  2011-06-12
# 3918     18282.0  2011-12-02
# 3919     18283.0  2011-12-06
# 3920     18287.0  2011-10-28
#
# [3921 rows x 2 columns]

# %%
df_recency.columns = ['CustomerID', 'last_purchased_date']
df_recency.head()
# Out:
#    CustomerID last_purchased_date
# 0     12346.0          2011-01-18
# 1     12747.0          2011-12-07
# 2     12748.0          2011-12-09
# 3     12749.0          2011-12-06
# 4     12820.0          2011-12-06

# %% [markdown]
# 4. Calculate the days since last purchase

# %%
df_recency["recency"] = (reference_date - df_recency["last_purchased_date"]).dt.days  # Son satın alma tarihinden itibaren geçen gün sayıları ile recency adlı yeni bir sütun oluşturdum
df_recency.head()
# Out:
#    CustomerID last_purchased_date  recency
# 0     12346.0          2011-01-18      326
# 1     12747.0          2011-12-07        3
# 2     12748.0          2011-12-09        1
# 3     12749.0          2011-12-06        4
# 4     12820.0          2011-12-06        4

# %% [markdown]
# 5. Drop Last_Purchase_Date since we don't need it anymore

# %%
df_recency = df_recency.drop(["last_purchased_date"], axis=1)  # recency adlı son satın alma tarihinden itibaren geçen gün sayıları içeren sütunu oluşturduktan sonra bu sütuna ihtiyacım kalmadı, düşürüyorum.

# %%
df_recency.head()
# Out:
#    CustomerID  recency
# 0     12346.0      326
# 1     12747.0        3
# 2     12748.0        1
# 3     12749.0        4
# 4     12820.0        4

# %% [markdown]
# 6. Plot RFM distributions

# %%
plt.figure(figsize=(12,7))
sns.distplot(df_recency.recency, kde=False, color='red')
# Out:
# <AxesSubplot:xlabel='recency'>

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# 1. Make a copy of df_uk and drop duplicates

# %%
df_uk2 = df_uk.copy()

# %%
df_uk2.drop_duplicates(subset=['InvoiceNo', 'CustomerID'], keep="first", inplace=True)

# %% [markdown]
# 2. Calculate the frequency of purchases

# %%
df_frequency = df_uk2.groupby(by='CustomerID', as_index=False)['InvoiceNo'].count()
df_frequency
# Out:
#       CustomerID  InvoiceNo
# 0        12346.0          1
# 1        12747.0         11
# 2        12748.0        210
# 3        12749.0          5
# 4        12820.0          4
# ...          ...        ...
# 3916     18280.0          1
# 3917     18281.0          1
# 3918     18282.0          2
# 3919     18283.0         16
# 3920     18287.0          3
#
# [3921 rows x 2 columns]

# %%
df_frequency.columns = ['CustomerID','frequency']
df_frequency.head()
# Out:
#    CustomerID  frequency
# 0     12346.0          1
# 1     12747.0         11
# 2     12748.0        210
# 3     12749.0          5
# 4     12820.0          4

# %% [markdown]
# 3. Plot RFM distributions

# %%
plt.figure(figsize=(12,7))
sns.countplot(df_frequency.frequency, color='red')
# frequency dağılımlarını gösteren bir plot çizdirdim
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='count'>

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# 1. Calculate sum total cost by customers and named "Monetary"

# %%
df_uk3 = df_uk.copy()

# %%
df_uk3.drop_duplicates(subset=['InvoiceNo', 'CustomerID'], keep="first", inplace=True)

# %%
df_uk3.head()
# Out:
#    InvoiceNo StockCode                         Description  Quantity  \
# 0     536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 7     536366     22633              HAND WARMER UNION JACK         6
# 9     536367     84879       ASSORTED COLOUR BIRD ORNAMENT        32
# 21    536368     22960            JAM MAKING SET WITH JARS         6
# 25    536369     21756            BATH BUILDING BLOCK WORD         3
#
#            InvoiceDate  UnitPrice  CustomerID         Country  total_revenue
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom          15.30
# 7  2010-12-01 08:28:00       1.85     17850.0  United Kingdom          11.10
# 9  2010-12-01 08:34:00       1.69     13047.0  United Kingdom          54.08
# 21 2010-12-01 08:34:00       4.25     13047.0  United Kingdom          25.50
# 25 2010-12-01 08:35:00       5.95     13047.0  United Kingdom          17.85

# %%
df_monetary = df_uk3.groupby(by='CustomerID',as_index=False).agg({'total_revenue': 'sum'})
df_monetary.head()
# Out:
#    CustomerID  total_revenue
# 0     12346.0       77183.60
# 1     12747.0         689.49
# 2     12748.0        3841.31
# 3     12749.0          98.35
# 4     12820.0          58.20

# %%
df_monetary.columns = ['CustomerID', 'monetary'] # her müşteriye ait harcama toplamları ile monetary adlı yeni bir sütun oluşturdum
df_monetary.head()
# Out:
#    CustomerID  monetary
# 0     12346.0  77183.60
# 1     12747.0    689.49
# 2     12748.0   3841.31
# 3     12749.0     98.35
# 4     12820.0     58.20

# %% [markdown]
# 2. Plot RFM distributions

# %%
plt.figure(figsize=(12,7))
sns.distplot(df_monetary.monetary, kde=False, color='red')
# müşterilerin büyük çoğunluğu ortalama 3800 civarı para harcıyor
# Out:
# <AxesSubplot:xlabel='monetary'>

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
df_merge_rf = df_recency.merge(df_frequency, on='CustomerID')
df_merge_rf.head()
# Out:
#    CustomerID  recency  frequency
# 0     12346.0      326          1
# 1     12747.0        3         11
# 2     12748.0        1        210
# 3     12749.0        4          5
# 4     12820.0        4          4

# %%
df_rfm = df_merge_rf.merge(df_monetary,on='CustomerID')
df_rfm.set_index('CustomerID',inplace=True)
df_rfm.head()
# Out:
#             recency  frequency  monetary
# CustomerID
# 12346.0         326          1  77183.60
# 12747.0           3         11    689.49
# 12748.0           1        210   3841.31
# 12749.0           4          5     98.35
# 12820.0           4          4     58.20

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# ***********************
# İşletmeler, müşterilerini anlamak için sürekli devam eden bir dürtüye sahiptir. Müşteriyi ne kadar iyi anlarsanız, onlara o kadar iyi hizmet verirsiniz ve o müşteriden elde ettiğiniz finansal kazanç o kadar yüksek olur. Ticaretin başlangıcından bu yana, stratejik bir kazanç için müşterileri anlama süreci orada uygulandı ve bu görev büyük ölçüde [Müşteri Segmentasyonu](https://clevertap.com/blog/rfm-analysis/) olarak biliniyor.
# Adından da anlaşılacağı gibi, Müşteri Segmentasyonu müşterileri kesin ihtiyaçlarına göre segmentlere ayırabilir. Müşterileri segmentlere ayırmanın yaygın yollarından bazıları, Yenilik-Sıklık-Monatoryal değerlerine, cinsiyet, bölge, ülke vb. gibi demografik özelliklerine ve işle ilgili bazı puanlarına dayanır. Bu durum için Yenilik-Frekans-Monatoryal değerlerini kullanacaksınız.
#
# Bu bölümde, müşterilerinizi RFM tablosunu kullanarak segmentlere ayırdığınız bir RFM Segmentasyon Tablosu oluşturacaksınız. Örneğin, en iyi müşteriyi "Büyük Harcayanlar" ve kayıp müşteriyi "Kayıp Müşteri" olarak etiketleyebilirsiniz.

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.
#
# ***********************
# ## RFM Puanını Hesapla
#
# Bir RFM modelinden müşteri segmentleri oluşturmanın en basit yolu **Çeyrekler** kullanmaktır. Her kategoriye (Yenilik, Sıklık ve Parasal) 1'den 4'e kadar bir puan vereceğiz ve 4 en yüksek/en iyi değer olacak. Nihai RFM puanı, tüm RFM değerlerinin birleştirilmesiyle hesaplanır. Müşteri Segmentasyonu için, RFM analizinden kaynaklanan df_rfm veri setini kullanacaksınız.
# <br>
# <br>
# **Not**: Daha iyi ayrıntı düzeyi için veriler daha fazla gruba atanabilir, ancak bu durumda 4 kullanacağız.

# %% [markdown]
# 1. Divide the df_rfm into quarters

# %%
df_rfm.shape
# Recency  : Son satın alma tarihinden itibaren geçen gün sayısı
# Frequency: Satın alma sayısı
# Monetary : Toplam harcama miktarı
# Out:
# (3921, 3)

# %%
df_rfm.describe().T
# Out:
#             count        mean          std  min   25%   50%    75%        max
# recency    3921.0   92.722265    99.528532  1.0  18.0  51.0  143.0     374.00
# frequency  3921.0    4.246111     7.205750  1.0   1.0   2.0    5.0     210.00
# monetary   3921.0  293.299913  3261.756525  0.0  17.7  45.4  124.5  168471.25

# %%
quantiles = df_rfm.quantile(q=[0.25,0.5,0.75])
quantiles
# Out:
#       recency  frequency  monetary
# 0.25     18.0        1.0      17.7
# 0.50     51.0        2.0      45.4
# 0.75    143.0        5.0     124.5

# %%
#quantiles.to_dict()

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# 1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.

# %%
def rscore(i,j,k):
    if i <= k[j][0.25]:
        return 4
    elif i <= k[j][0.50]:
        return 3
    elif i <= k[j][0.75]: 
        return 2
    else:
        return 1

# %%
def fm_score(i,j,k):
    if i <= k[j][0.25]:
        return 1
    elif i <= k[j][0.50]:
        return 2
    elif i <= k[j][0.75]: 
        return 3
    else:
        return 4

# %% [markdown]
# 2. Score customers from 1 to 4 by applying the functions you have created. Also create separate score column for each value.

# %%
df_rfm_seg = df_rfm.copy()
df_rfm_seg
# Out:
#             recency  frequency  monetary
# CustomerID
# 12346.0         326          1  77183.60
# 12747.0           3         11    689.49
# 12748.0           1        210   3841.31
# 12749.0           4          5     98.35
# 12820.0           4          4     58.20
# ...             ...        ...       ...
# 18280.0         278          1     23.70
# 18281.0         181          1      5.04
# 18282.0           8          2     38.25
# 18283.0           4         16     66.75
# 18287.0          43          3     80.40
#
# [3921 rows x 3 columns]

# %%
df_rfm_seg['recency_score'] = df_rfm_seg["recency"].apply(rscore, args=('recency',quantiles))

# %%
df_rfm_seg["frequency_score"] = df_rfm_seg["frequency"].apply(fm_score, args=('frequency',quantiles))

# %%
df_rfm_seg["monetary_score"] = df_rfm_seg["monetary"].apply(fm_score, args=('monetary',quantiles))

# %%
df_rfm_seg.head()
# Out:
#             recency  frequency  monetary  recency_score  frequency_score  \
# CustomerID
# 12346.0         326          1  77183.60              1                1
# 12747.0           3         11    689.49              4                4
# 12748.0           1        210   3841.31              4                4
# 12749.0           4          5     98.35              4                3
# 12820.0           4          4     58.20              4                3
#
#             monetary_score
# CustomerID
# 12346.0                  4
# 12747.0                  4
# 12748.0                  4
# 12749.0                  3
# 12820.0                  3

# %% [markdown]
# 3. Now that scored each customer, you'll combine the scores for segmentation.

# %%
df_rfm_seg["RFM_score"]= df_rfm_seg["recency_score"].astype(str)+df_rfm_seg["frequency_score"].astype(str)+df_rfm_seg["monetary_score"].astype(str)
df_rfm_seg.head()
# Out:
#             recency  frequency  monetary  recency_score  frequency_score  \
# CustomerID
# 12346.0         326          1  77183.60              1                1
# 12747.0           3         11    689.49              4                4
# 12748.0           1        210   3841.31              4                4
# 12749.0           4          5     98.35              4                3
# 12820.0           4          4     58.20              4                3
#
#             monetary_score RFM_score
# CustomerID
# 12346.0                  4       114
# 12747.0                  4       444
# 12748.0                  4       444
# 12749.0                  3       433
# 12820.0                  3       433

# %%
df_rfm_seg.columns   #ısrarla alttaki kod çalışmadı. sütun ismini doğru almamış olabileceğini düşündüm. öyleymiş.
# Out:
# Index(['recency', 'frequency', 'monetary', 'recency_score', 'frequency_score',
#        'monetary_score', 'RFM_score'],
#       dtype='object')

# %% [markdown]
# 4. Define rfm_level function that tags customers by using RFM_Scrores and Create a new variable RFM_Level

# %%
def rfm_level(df):                                   # rfm level fonksiyonu
    
    if df['RFM_score'] == "444":
        return 'Best Customers'
    elif ((df['frequency_score'] == '4')):
        return 'Loyal Customers'
    elif ((df['monetary_score'] == '4')):
        return 'Big Spenders'
    elif ((df['RFM_score'] == '244')):
        return 'Almost Lost'
    elif ((df['RFM_score'] == '144')):
        return 'Lost Customers'
    elif ((df['RFM_score'] == '111')):
        return 'Lost Cheap Customers'

# %%
df_rfm_seg['RFM_Level'] = df_rfm_seg.apply(rfm_level, axis=1)   # RFM_Level sütununu oluşturdum

# %%
df_rfm_seg
# Out:
#             recency  frequency  monetary  recency_score  frequency_score  \
# CustomerID
# 12346.0         326          1  77183.60              1                1
# 12747.0           3         11    689.49              4                4
# 12748.0           1        210   3841.31              4                4
# 12749.0           4          5     98.35              4                3
# 12820.0           4          4     58.20              4                3
# ...             ...        ...       ...            ...              ...
# 18280.0         278          1     23.70              1                1
# 18281.0         181          1      5.04              1                1
# 18282.0           8          2     38.25              4                2
# 18283.0           4         16     66.75              4                4
# 18287.0          43          3     80.40              3                3
#
#             monetary_score RFM_score             RFM_Level
# CustomerID
# ...

# %%
df_rfm_seg.RFM_Level.value_counts()
# Out:
# Lost Cheap Customers    377
# Best Customers          370
# Almost Lost              65
# Lost Customers           11
# Name: RFM_Level, dtype: int64

# %% [markdown]
# 5. Calculate average values for each RFM_Level, and return a size of each segment

# %%
rfm_level_agg = df_rfm_seg.groupby('RFM_Level').agg({
    'recency': 'mean',
    'frequency': 'mean',
    'monetary': 'mean'
}).round(1)

# %%
print(rfm_level_agg)
# Out:
#                       recency  frequency  monetary
# RFM_Level
# Best Customers            7.7       16.8    1237.6
# Big Spenders             91.7        3.1    1125.5
# Lost Cheap Customers    262.1        1.0      10.5
# Loyal Customers          43.6        8.8     359.5
# Other Customers          87.9        2.2      39.6

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# 1. Create your plot and resize it.

# %%
plt.figure(figsize=(15,10))
ax= sns.countplot(x='RFM_Level',data=df_rfm_seg)
ax.bar_label(ax.containers[0], fontsize=12, fontweight="bold");

# %%
df_rfm_seg.loc[df_rfm_seg.index == 12821.0]    # customer id leri index yaptığımdan bu şekilde ulaşıp RFM level ini görebiliyorum
# Out:
#             recency  frequency  monetary  recency_score  frequency_score  \
# CustomerID
# 12821.0         215          1     19.92              1                1
#
#             monetary_score RFM_score        RFM_Level
# CustomerID
# 12821.0                  2       112  Other Customers

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales). We can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %% [markdown]
# 2. How many customers do we have in each segment?

# %%
df_rfm_seg.columns
# Out:
# Index(['recency', 'frequency', 'monetary', 'recency_score', 'frequency_score',
#        'monetary_score', 'RFM_score', 'RFM_Level'],
#       dtype='object')

# %%
print("Best Customers: ",len(df_rfm_seg[df_rfm_seg['RFM_score']=='444']))
print('Loyal Customers: ',len(df_rfm_seg[df_rfm_seg['frequency_score']==4]))
print("Big Spenders: ",len(df_rfm_seg[df_rfm_seg['monetary_score']==4]))
print('Almost Lost: ', len(df_rfm_seg[df_rfm_seg['RFM_score']=='244']))
print('Lost Customers: ',len(df_rfm_seg[df_rfm_seg['RFM_score']=='144']))
print('Lost Cheap Customers: ',len(df_rfm_seg[df_rfm_seg['RFM_score']=='111']))
# Out:
# Best Customers:  370
# Loyal Customers:  791
# Big Spenders:  980
# Almost Lost:  65
# Lost Customers:  11
# Lost Cheap Customers:  377

# %% [markdown]
# Insights:
#
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# # 3. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into different categories, we can gain further insight into customer behavior by using predictive models in conjuction with out RFM model.
# Possible algorithms include **Logistic Regression**, **K-means Clustering**, and **K-nearest Neighbor**. We will go with [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) since we already have our distinct groups determined. K-means has also been widely used for market segmentation and has the advantage of being simple to implement.
#
# Artık müşterilerimizi farklı kategorilere ayırdığımıza göre, RFM modeliyle bağlantılı olarak tahmine dayalı modelleri kullanarak müşteri davranışı hakkında daha fazla bilgi edinebiliriz.
# Olası algoritmalar arasında **Lojistik Regresyon**, **K-ortalama Kümeleme** ve **K-en yakın Komşu** bulunur. Farklı gruplarımızı zaten belirlediğimiz için [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) ile gideceğiz. K-araçları ayrıca pazar bölümlendirme için yaygın olarak kullanılmaktadır ve uygulanması basit olma avantajına sahiptir.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree
from pyclustertend import hopkins

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %%
rfm_

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# 1. Logarithmic Tranformation can be used to normalize the values in a column.
# 2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.

# %% [markdown]
# ## K-Means Implementation
#
# For k-means, you have to set k to the number of clusters you want, but figuring out how many clusters is not obvious from the beginning. We will try different cluster numbers and check their [silhouette coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html). The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# <br>
# <br>
# **Note**: K-means is sensitive to initializations because they are critical to qualifty of optima found. Thus, we will use smart initialization called "Elbow Method".

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %% [markdown]
# ### ii. Model Fitting

# %% [markdown]
# Fit the K-Means Algorithm with the optimal number of clusters you decided and save the model to disk.

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# 1. Create a scatter plot and select cluster centers

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %% [markdown]
# ### iv. Assign the Label

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the RFM Customer Segmentation with the labels found by K-Means.

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %% [markdown]
# **Annotation:**
#
# Limitations of K-means clustering:
#
# 1. There is no assurance that it will lead to the global best solution.
# 2. Can't deal with different shapes(not circular) and consider one point's probability of belonging to more than one cluster.
#
# These disadvantages of K-means show that for many datasets (especially low-dimensional datasets), it may not perform as well as you might hope.

# %% [markdown]
# **Conclusion**
#
# * Write down your conclusions about clustering

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %% [markdown]
# Now we will use the function created above to convert all the invoice dates into respective month date format.

# %% [markdown]
# ### ii. Calculating time offset in Months i.e. Cohort Index:
# Calculating time offset for each transaction will allows us to report the metrics for each cohort in a comparable fashion.
# First, you will create 4 variables that capture the integer value of years, months for Invoice and Cohort Date using the get_date_int() function which you'll create it below.

# %% [markdown]
# You will use this function to extract the integer values for Invoice as well as Cohort Date in 3 separate series for each of the two columns

# %% [markdown]
# Use the variables created above to calcualte the difference in days and store them in cohort Index column.

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
